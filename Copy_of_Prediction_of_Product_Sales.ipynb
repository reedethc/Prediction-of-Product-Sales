# %% [markdown]
# <a href="https://colab.research.google.com/github/reedethc/Prediction-of-Product-Sales/blob/main/Copy_of_Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project: Prediction of Product Sales
# - Author: Red Mataragkas
# ---
# ## "Project Overview"
# - The first project will be a sales prediction for food items sold at various stores. The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales.
# ---

# %% [markdown]
# ## "Load and Inspect Data"
# ---

# %%
#Insert code below the heading "Loading Data"
#Use Pandas to read the sales prediction data set into Google Colab.
#Use df.info() and df.head() methods to preview the first rows of your data and a summary of your DataFrame's columns.

# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import required packages
import numpy as np
import pandas as pd

# Save the filepath and load the data as "df_titanic"
fname = '/content/drive/MyDrive/Coding Dojo/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'
df_salespr = pd.read_csv(fname)

# %%
#inspect first 5 rows
df_salespr.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#inspect last 5 rows
df_salespr.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %% [markdown]
# ## "Clean Data"
# ---

# %% [markdown]
# Insert code below the heading "Data Cleaning"
#
# Explore the data - what do you need to do to clean this data? Clean it!
# Be sure to address each of the following tasks:
#
# 1) How many rows and columns?
# - there are 8523 rows and 12 columns in this dataset

# %%
#Determine how many rows and columns
df_salespr.shape
# Out:
# (8523, 12)

# %% [markdown]
# 2) What are the datatypes of each variable?

# %%
df_salespr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 3) Are there duplicates? If so, drop any duplicates.

# %%
dup_rows = df_salespr.duplicated()
dup_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
#Drop any duplicates
df_salespr.duplicated().sum()
# Out:
# 0

# %%
df_salespr[dup_rows]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
df_salespr.duplicated(subset=['Item_Identifier'], keep=False).sum()
# Out:
# 8514

# %% [markdown]
# 4) Identify missing values.

# %%
null_sums= df_salespr.isna().sum()
null_sums
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Item_Weight and Outlet_Size have missing values

# %%
df_salespr['Item_Identifier'].nunique()/len(df_salespr)*100
# Out:
# 18.291681332864016

# %% [markdown]
# 5) Address the missing values by using a placeholder value.

# %%
df_salespr['Item_Weight']=df_salespr['Item_Weight'].fillna(0)

# %%
df_salespr['Outlet_Size']=df_salespr['Outlet_Size'].fillna("MISSING")

# %% [markdown]
# 6) Confirm that there are no missing values after addressing them.

# %%
null_sums= df_salespr.isna().sum()
null_sums
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# 7) Find and fix any inconsistent categories of data (for example: fix cat, Cat, and cats so that they are consistent).

# %%
df_salespr['Item_Fat_Content']=df_salespr['Item_Fat_Content'].replace({'LF':"Low Fat",'low fat':"Low Fat",'reg':"Regular"})
df_salespr['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# 8) For any numerical columns, obtain the summary statistics of each (min, max, mean).

# %%
num_cols=df_salespr.select_dtypes("number").columns
df_salespr[num_cols].describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     10.650590         0.066132   140.992782                1997.831867
# std       6.431899         0.051598    62.275067                   8.371760
# min       0.000000         0.000000    31.290000                1985.000000
# 25%       6.650000         0.026989    93.826500                1987.000000
# 50%      11.000000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df_salespr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## "Exploratory Data Analysis"
# ---

# %% [markdown]
# ## "Feature Inspection"
